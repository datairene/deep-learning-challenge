# %%
# Import our dependencies
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.datasets import make_blobs
import sklearn as skl
import tensorflow as tf

# %%
# Generate dummy dataset
X, y = make_blobs(n_samples=1000, centers=2, n_features=2, random_state=78)

# Creating a DataFrame with the dummy data
df = pd.DataFrame(X, columns=["Feature 1", "Feature 2"])
df["Target"] = y

# Plotting the dummy data
df.plot.scatter(x="Feature 1", y="Feature 2", c="Target", colormap="winter")
plt.show()

# %%
# Use sklearn to split dataset
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=78)

# %%
# Create scaler instance
X_scaler = skl.preprocessing.StandardScaler()

# Fit the scaler
X_scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %%
# Create the Keras Sequential model
nn_model = tf.keras.models.Sequential()

# %%
# Add our first Dense layer, including the input layer
nn_model.add(tf.keras.layers.Dense(units=5, activation="relu", input_dim=2))

# %%
# Add the output layer that uses a probability activation function
nn_model.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))

# %%
# Check the structure of the Sequential model
nn_model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_2 (Dense)             (None, 5)                 15
#
#  dense_3 (Dense)             (None, 1)                 6
#
# =================================================================
# Total params: 21 (84.00 Byte)
# Trainable params: 21 (84.00 Byte)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# Compile the Sequential model together and customize metrics
nn_model.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# Fit the model to the training data
fit_model = nn_model.fit(X_train_scaled, y_train, epochs=100)
# Out:
# Epoch 1/100
# 24/24 [==============================] - 1s 2ms/step - loss: 0.7275 - accuracy: 0.2733
# Epoch 2/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.7009 - accuracy: 0.4840
# Epoch 3/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.6777 - accuracy: 0.6787
# Epoch 4/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.6568 - accuracy: 0.7280
# Epoch 5/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.6363 - accuracy: 0.7800
# Epoch 6/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.6159 - accuracy: 0.8307
# Epoch 7/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.5946 - accuracy: 0.8680
# Epoch 8/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.5724 - accuracy: 0.8960
# Epoch 9/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.5491 - accuracy: 0.9240
# Epoch 10/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.5251 - accuracy: 0.9533
# Epoch 11/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.5004 - accuracy: 0.9760
# Epoch 12/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.4757 - accuracy: 0.9867
# Epoch 13/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.4512 - accuracy: 0.9933
# Epoch 14/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.4279 - accuracy: 0.9973
# Epoch 15/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.4061 - accuracy: 0.9987
# Epoch 16/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3861 - accuracy: 0.9987
# Epoch 17/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3681 - accuracy: 1.0000
# Epoch 18/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3516 - accuracy: 1.0000
# Epoch 19/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3368 - accuracy: 1.0000
# Epoch 20/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3233 - accuracy: 1.0000
# Epoch 21/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3110 - accuracy: 1.0000
# Epoch 22/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2997 - accuracy: 1.0000
# Epoch 23/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2894 - accuracy: 1.0000
# Epoch 24/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2798 - accuracy: 1.0000
# Epoch 25/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2710 - accuracy: 1.0000
# Epoch 26/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2627 - accuracy: 1.0000
# Epoch 27/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2550 - accuracy: 1.0000
# Epoch 28/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2477 - accuracy: 1.0000
# Epoch 29/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2408 - accuracy: 1.0000
# Epoch 30/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2344 - accuracy: 1.0000
# Epoch 31/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2283 - accuracy: 1.0000
# Epoch 32/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2225 - accuracy: 1.0000
# Epoch 33/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2169 - accuracy: 1.0000
# Epoch 34/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2116 - accuracy: 1.0000
# Epoch 35/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2066 - accuracy: 1.0000
# Epoch 36/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2017 - accuracy: 1.0000
# Epoch 37/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.1970 - accuracy: 1.0000
# Epoch 38/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.1924 - accuracy: 1.0000
# Epoch 39/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.1880 - accuracy: 1.0000
# Epoch 40/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.1837 - accuracy: 1.0000
# Epoch 41/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.1795 - accuracy: 1.0000
# Epoch 42/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.1753 - accuracy: 1.0000
# Epoch 43/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.1710 - accuracy: 1.0000
# Epoch 44/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.1666 - accuracy: 1.0000
# Epoch 45/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.1618 - accuracy: 1.0000
# Epoch 46/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.1562 - accuracy: 1.0000
# Epoch 47/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.1493 - accuracy: 1.0000
# Epoch 48/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.1410 - accuracy: 1.0000
# Epoch 49/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.1317 - accuracy: 1.0000
# Epoch 50/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.1216 - accuracy: 1.0000
# Epoch 51/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.1111 - accuracy: 1.0000
# Epoch 52/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.1006 - accuracy: 1.0000
# Epoch 53/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0906 - accuracy: 1.0000
# Epoch 54/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0811 - accuracy: 1.0000
# Epoch 55/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0726 - accuracy: 1.0000
# Epoch 56/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0649 - accuracy: 1.0000
# Epoch 57/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0581 - accuracy: 1.0000
# Epoch 58/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0521 - accuracy: 1.0000
# Epoch 59/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0469 - accuracy: 1.0000
# Epoch 60/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0424 - accuracy: 1.0000
# Epoch 61/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0384 - accuracy: 1.0000
# Epoch 62/100
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0350 - accuracy: 1.0000
# Epoch 63/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0320 - accuracy: 1.0000
# Epoch 64/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0293 - accuracy: 1.0000
# Epoch 65/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0270 - accuracy: 1.0000
# Epoch 66/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0249 - accuracy: 1.0000
# Epoch 67/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0231 - accuracy: 1.0000
# Epoch 68/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0215 - accuracy: 1.0000
# Epoch 69/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0200 - accuracy: 1.0000
# Epoch 70/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0187 - accuracy: 1.0000
# Epoch 71/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0175 - accuracy: 1.0000
# Epoch 72/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0164 - accuracy: 1.0000
# Epoch 73/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0155 - accuracy: 1.0000
# Epoch 74/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0146 - accuracy: 1.0000
# Epoch 75/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0137 - accuracy: 1.0000
# Epoch 76/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0130 - accuracy: 1.0000
# Epoch 77/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0123 - accuracy: 1.0000
# Epoch 78/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0117 - accuracy: 1.0000
# Epoch 79/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0111 - accuracy: 1.0000
# Epoch 80/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0106 - accuracy: 1.0000
# Epoch 81/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0101 - accuracy: 1.0000
# Epoch 82/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0096 - accuracy: 1.0000
# Epoch 83/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0092 - accuracy: 1.0000
# Epoch 84/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0088 - accuracy: 1.0000
# Epoch 85/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0084 - accuracy: 1.0000
# Epoch 86/100
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0080 - accuracy: 1.0000
# Epoch 87/100
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0077 - accuracy: 1.0000
# Epoch 88/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0074 - accuracy: 1.0000
# Epoch 89/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0071 - accuracy: 1.0000
# Epoch 90/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0068 - accuracy: 1.0000
# Epoch 91/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0066 - accuracy: 1.0000
# Epoch 92/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0063 - accuracy: 1.0000
# Epoch 93/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0061 - accuracy: 1.0000
# Epoch 94/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0059 - accuracy: 1.0000
# Epoch 95/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0057 - accuracy: 1.0000
# Epoch 96/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0055 - accuracy: 1.0000
# Epoch 97/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0053 - accuracy: 1.0000
# Epoch 98/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0051 - accuracy: 1.0000
# Epoch 99/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0049 - accuracy: 1.0000
# Epoch 100/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0048 - accuracy: 1.0000

# %%
# Create a DataFrame containing training history
history_df = pd.DataFrame(fit_model.history)

# Increase the index by 1 to match the number of epochs
history_df.index += 1

# Plot the loss
history_df.plot(y="loss")
plt.show()

# %%
# Plot the accuracy
history_df.plot(y="accuracy")
plt.show()

# %%
# Evaluate the model using the test data
model_loss, model_accuracy = nn_model.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: (model_loss), Accuracy: (model_accuracy)")
# Out:
# 8/8 - 0s - loss: 0.0044 - accuracy: 1.0000 - 168ms/epoch - 21ms/step
# Loss: (model_loss), Accuracy: (model_accuracy)
